# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from csv import writer
from csv import reader
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier 
from sklearn.linear_model import LinearRegression
warnings.simplefilter('ignore')

# %%
#target --> class : 1 Fraud | 0 ok 
labels = pd.read_csv('labels.csv')
labels_test = labels.head(100)
labels_test
# Out:
#     Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0            0      3            0                   0        3      2
# 1            1      3            0                   3        0      1
# 2            2      3            0                   3        0      1
# 3            3      3            0                   2        1      1
# 4            4      6            0                   6        0      1
# ..         ...    ...          ...                 ...      ...    ...
# 95          96      3            0                   3        0      1
# 96          97      3            0                   3        0      1
# 97          98      3            0                   3        0      1
# 98          99      3            0                   3        0      1
# 99         100      3            1                   2        0      1
#
#                                                 tweet
# 0   !!! RT @mayasolovely: As a woman you shouldn't...
# ...

# %%
for i, row in labels_test.iterrows():

    tweet = str(row["tweet"])

    if tweet.find(';') != -1 :
        tweet = tweet.replace (";"," ")
    
    if tweet.find('"') != -1:
        tweet = tweet.replace ('"'," ")

    if tweet.find('&') != -1 :
        tweet = ' '.join(filter(lambda x:x[0]!='&', tweet.split()))
        labels_test.at[i, "tweet"] = ' '.join(filter(lambda x:x[0]!='&', tweet.split()))
        tweet = str(row["tweet"])

    while tweet.find('&') != -1 :
        a = tweet.find('&') -1
        tweet = tweet[:(a+1)] + " " + tweet[(a+1):]
        tweet = ' '.join(filter(lambda x:x[0]!='&', tweet.split()))

labels_test
# Out:
#     Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0            0      3            0                   0        3      2
# 1            1      3            0                   3        0      1
# 2            2      3            0                   3        0      1
# 3            3      3            0                   2        1      1
# 4            4      6            0                   6        0      1
# ..         ...    ...          ...                 ...      ...    ...
# 95          96      3            0                   3        0      1
# 96          97      3            0                   3        0      1
# 97          98      3            0                   3        0      1
# 98          99      3            0                   3        0      1
# 99         100      3            1                   2        0      1
#
#                                                 tweet
# 0   !!! RT @mayasolovely: As a woman you shouldn't...
# ...

# %%
#encodage 
from sklearn.preprocessing import LabelEncoder
X = labels_test[labels_test[:-1]]
y = labels_test['class']
tweet_labelEncoder = LabelEncoder()
X['tweet'] = tweet_labelEncoder.fit_transform(labels_test['tweet'])
